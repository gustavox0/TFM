# %% [markdown]
# <a href="https://colab.research.google.com/github/gustavox0/TFM/blob/main/plantilla_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. Portada
# **Título del trabajo:** Informe del Proyecto
# **Autor:** Tu Nombre
# **Fecha:** Mayo 2025
#
# ![](https://upload.wikimedia.org/wikipedia/commons/thumb/9/95/Logo_UNAM.svg/1200px-Logo_UNAM.svg.png)

# %% [markdown]
# # 2. Índice
# 1. Resumen ejecutivo
# 2. Objetivos
#    a) Objetivo principal
#    b) Antecedentes
#    c) Punto de partida
#    d) Stakeholders
#    e) DAFO
# 3. Desarrollo
#    a) Timing del proyecto
#       i. Fases del proyecto
#       ii. Análisis económico
# 4. Conclusiones

# %% [markdown]
# # 3. Resumen ejecutivo
# Describe brevemente los objetivos del proyecto, los resultados esperados y el impacto esperado.

# %% [markdown]
# # 4. Objetivos
# ## a) Objetivo principal
# Describir el objetivo general del proyecto.
# ## b) Antecedentes
# Contexto y justificación del problema.
# ## c) Punto de partida
# Estado actual de la situación.
# ## d) Stakeholders
# Lista de actores clave involucrados.
# ## e) DAFO
# - **Debilidades:**
# - **Amenazas:**
# - **Fortalezas:**
# - **Oportunidades:**

# %% [markdown]
# # 5. Desarrollo
# ## a) Timing del proyecto
# ### i. Fases del proyecto
# Describa las etapas del proyecto aquí.
# ### ii. Análisis económico
# Incluya aquí gráficos y análisis económicos realizados con Python:

# %%
# Ejemplo de análisis económico en Python
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 10, 100)
y = np.sin(x)
plt.plot(x, y)
plt.title("Ejemplo de gráfico")
plt.xlabel("Tiempo")
plt.ylabel("Resultado")
plt.grid(True)
plt.show()

# %% [markdown]
# # 6. Conclusiones
# Resumen de aprendizajes, logros y próximos pasos.
